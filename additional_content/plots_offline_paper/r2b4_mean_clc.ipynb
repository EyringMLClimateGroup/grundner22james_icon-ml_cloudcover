# %% [markdown]
# **For Figure 4b**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib

# Increase the general font size in plots
size_plots_label = 11
matplotlib.rcParams['legend.fontsize'] = size_plots_label
matplotlib.rcParams['axes.labelsize'] = size_plots_label # For an axes xlabel and ylabel
matplotlib.rcParams['axes.titlesize'] = size_plots_label+2 # For an axes xlabel and ylabel
matplotlib.rcParams['xtick.labelsize'] = size_plots_label
matplotlib.rcParams['ytick.labelsize'] = size_plots_label

# Averaged over the NARVAL region
zg_mean_narval = [20785,19153,17604,16134,14741,13422,12175,10998,9890,8848,
                  7871,6958,6107,5317,4587,3915,3300,2741,2237,1787,1390,1046,
                  754,515,329,199,128] # in meters

zg_mean_narval = np.round(np.array(zg_mean_narval)/1000, decimals=1) # in kilometers

# Averaged globally
zg_mean_qubicc = [20785,19153,17604,16134,14742,13424,12178,11002,9896,8857,
                  7885,6977,6133,5351,4630,3968,3363,2814,2320,1878,1490,1153,
                  867,634,452,324,254] # in meters
zg_mean_qubicc = np.round(np.array(zg_mean_qubicc)/1000, decimals=1) # in kilometers

green='#004D40'
red='#D81B60'
blue='#1E88E5'

# %% [markdown]
# The mean profiles are computed for the first NN from each NN type respectively

# %%
# Taken from the respective interpretation ipynb-notebooks
data_mean = [2.0516477693020423e-07,0.00034086927341436753,0.17661084202334312,1.4998438126611484,3.902263484035136,6.349001448225982,6.547815854066336,5.033804978480318,3.448304713902622,2.5793811697820677,1.92561651328619,1.667549647945401,1.9866840386031737,2.452039861399841,2.20654246164629,1.7451326114003243,1.9593509079281894,2.7583582117141883,4.166830828417757,6.908296338684412,10.76565897432415,13.262349346144319,10.728780853117888,4.325431446378538,0.9917836019502414,0.33945893908952796,0.1554966481012375]
region_based_mean = [0.00019869,0.00028952,0.17292088,1.5057614,3.9511752,6.42019,6.534646,5.09313,3.4730515,2.5862944,1.9298049,1.6620936,2.0024312,2.4604807,2.221365,1.7741598,1.9854069,2.744725,4.2037177,6.894963,10.748404,13.222322,10.732124,4.2999697,1.0032209,0.34955263,0.15560368]
column_based_mean =  [ 0.01957798,  0.05253388,  0.16547991,  1.5168297 ,  3.9382503 ,6.32812   ,  6.4934864 ,  5.024541  ,  3.3790243 ,  2.5882218 ,1.9968994 ,  1.7662972 ,  2.117203  ,  2.5311933 ,  2.2601795 ,1.9334778 ,  2.0583446 ,  2.8288033 ,  4.2522674 ,  6.967667  ,10.492099  , 13.341855  , 10.741383  ,  4.3720226 ,  1.0384021 ,0.37790278,  0.17620933]
cell_based_mean = [0.1635533,0.17032495,0.28294036,1.6375923,4.0405183,6.566985,6.491137,5.1089425,3.4329896,2.6194272,2.0605946,1.7654794,2.1055267,2.5771666,2.2690954,1.7307017,1.9348546,2.7798536,4.2401667,6.9686007,10.7315035,13.304247,10.711859,4.12894,1.2561029,0.74989486,0.6141081]

# %% [markdown]
# The R2-values are computed for the first NN from each NN type respectively

# %%
# Taken from the respective interpretation ipynb-notebooks
region_based_r2 = [-2131169.4218093962,0.9340452725543076,0.9815382094872405,0.9875779569711387,0.9881498169204237,0.985849414939333,0.9845079819136472,0.9859554777867869,0.9890010192649976,0.9895664135327232,0.9874473960792923,0.985320558548991,0.9861261160817199,0.989554547743751,0.9907844996557563,0.9907635695408146,0.9910925442584202,0.9914023282208477,0.9918668692237637,0.9926304087669037,0.9941627854374602,0.9953104492050667,0.9962050284220396,0.9951965485999752,0.991702810938895,0.9858218918378474,0.9760560897393651]
column_based_r2 = [-720361.4375716654,-13.46696667620228,0.8385921147746853,0.9532664857642843,0.9720653749076086,0.9742194217759714,0.9747798946868595,0.9769401140222785,0.9799722297191754,0.9788840637139712,0.9720775253716636,0.9698965616759012,0.9716782236325857,0.975023001538734,0.9789519124215493,0.9745725365015382,0.9788270528067893,0.9825510640733438,0.9837219613550517,0.985948548211242,0.9877470727713877,0.9903804562007693,0.9906706118552346,0.986886762085533,0.97453770971961,0.9537738471453958,0.9179424146309695]
cell_based_r2 = [-5288011.708931549,-66.82464192315824,0.8250699442653973,0.8357615218109444,0.8322658779596421,0.8058549066161531,0.8677042814906145,0.9064434846872566,0.9228692537339417,0.9115434235965795,0.872814675642628,0.8480285425458993,0.8349127157336194,0.8338951356873923,0.8261199712878826,0.774354077451422,0.7852936153756118,0.8087000118148016,0.819515544587062,0.806677245981631,0.7817166468676764,0.7958429718943567,0.8977171754721437,0.8938475923096937,0.8155762808324988,0.6580476419833761,0.2629158100038722]

# %%
fig = plt.figure()

# Mean cloud cover plot
a = np.linspace(21, 47, 27)
ax = fig.add_subplot(111, xlabel='Mean cloud cover [%]', ylabel='z [km]')
ax.plot(cell_based_mean, zg_mean_narval, color='#004D40', alpha=.7)
ax.plot(column_based_mean, zg_mean_narval, color='#D81B60', alpha=.7)
ax.plot(region_based_mean, zg_mean_narval, color='#1E88E5', alpha=.7)
ax.plot(data_mean, zg_mean_narval, 'k')
ax.grid(b=True)
ax.legend(['Cell-based model', 'Column-based model', 'Neighborhood-based model', 'Ground truth'])
# plt.gca().invert_yaxis()

fig.savefig('figures/r2b4_combined_mean_clc.pdf')

# %%
fig = plt.figure(figsize=(15,5))

# Mean cloud cover plot
a = np.linspace(21, 47, 27)
ax = fig.add_subplot(121, xlabel='Mean Cloud Cover', ylabel='Vertical layer')
ax.plot(cell_based_mean, a, 'g', alpha=.7)
ax.plot(column_based_mean, a, 'r', alpha=.7)
ax.plot(region_based_mean, a, 'b', alpha=.7)
ax.plot(data_mean, a, 'k')
ax.grid(b=True)
ax.legend(['Cell-based Model', 'Column-based Model', 'Region-based Model', 'Ground Truth'])
plt.gca().invert_yaxis()

# R2 plot
a = np.linspace(23, 47, 25)
ax_2 = fig.add_subplot(122, xlim=(0.2, 1), xlabel='$R^2$-value')
ax_2.plot(cell_based_r2[2:], a, 'go-', linewidth=1)
ax_2.plot(column_based_r2[2:], a, 'ro-', linewidth=1)
ax_2.plot(region_based_r2[2:], a, 'bo-', linewidth=1)
ax_2.grid(b=True)
ax_2.legend(['Cell-based model', 'Column-based model', 'Region-based model'])
plt.gca().invert_yaxis()

# fig.savefig('figures/r2b4_combined_mean_clc_and_r2.pdf')
