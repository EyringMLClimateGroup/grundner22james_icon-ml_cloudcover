# %% [markdown]
# **For Figure 5**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib

# Increase the general font size in plots
size_plots_label = 11
matplotlib.rcParams['legend.fontsize'] = size_plots_label
matplotlib.rcParams['axes.labelsize'] = size_plots_label # For an axes xlabel and ylabel
matplotlib.rcParams['axes.titlesize'] = size_plots_label+2 # For an axes xlabel and ylabel
matplotlib.rcParams['xtick.labelsize'] = size_plots_label
matplotlib.rcParams['ytick.labelsize'] = size_plots_label

# Averaged over the NARVAL region
zg_mean_narval = [20785,19153,17604,16134,14741,13422,12175,10998,9890,8848,
                  7871,6958,6107,5317,4587,3915,3300,2741,2237,1787,1390,1046,
                  754,515,329,199,128] # in meters

zg_mean_narval = np.round(np.array(zg_mean_narval)/1000, decimals=1) # in kilometers

# Averaged globally
zg_mean_qubicc = [20785,19153,17604,16134,14742,13424,12178,11002,9896,8857,
                  7885,6977,6133,5351,4630,3968,3363,2814,2320,1878,1490,1153,
                  867,634,452,324,254] # in meters
zg_mean_qubicc = np.round(np.array(zg_mean_qubicc)/1000, decimals=1) # in kilometers

# color_1='#56B4E9'
# color_2='#009E73'
# color_3='#E69F00'

color_1='#117733'
color_2='#E69F00'
color_3='#332288'

# %% [markdown]
# #### Cell-based model Validation folds

# %% [markdown]
# Cloud Volume Fraction

# %%
# Taken from the respective interpretation ipynb-notebooks
fold_1_predictions = [0.0028432222406232647, 0.0007034557848768701, 0.009137614601594584, 1.3690991534716983, 11.451968721468127, 23.5649726006253, 24.70086216026294, 23.30477859090515, 24.31446072473635, 25.900491414377733, 24.620579145925795, 21.51859973453259, 18.069290913963346, 15.484319593893195, 13.710795782670289, 12.817580372103413, 12.326052884522893, 12.304526652289612, 12.93788566725108, 13.998254227562215, 15.246311696745417, 13.527119928768375, 11.347410175978295, 10.224435695280876, 10.122216205098715, 11.103418825706914, 14.112578196497067]
fold_1_truth = [7.301722939482133e-06, 0.00017961007012210492, 0.013444670559989852, 1.605182518055523, 11.469676776950338, 21.49832572910905, 23.963564476266637, 23.944858520423164, 24.979989181308003, 26.465901816177148, 25.62176833294008, 22.295252089028196, 18.171435219398724, 15.394187208473847, 13.409362253833702, 12.490956128865484, 12.015382461891301, 12.025559857096553, 12.781704012589245, 14.036424824179933, 15.550633728946874, 14.068713282846845, 11.927454601944543, 10.707060067578904, 10.561219548997762, 11.478539171413754, 13.641042585699646]
fold_2_predictions = [0.4641874024194031, 0.16188227257813245, 0.032514571751988484, 1.8785493370419106, 11.300346033888154, 20.474254783442756, 23.847784348024845, 23.569236895794518, 24.85818983784599, 26.903309121474212, 25.42009754376629, 21.677537419922277, 17.86268425979063, 15.43588002463639, 14.071247645010745, 13.109662271213889, 12.414668054174685, 12.3920361380486, 12.97173380738487, 13.994576513002782, 15.67957663391172, 14.446918083405881, 12.152390790114419, 10.72874879913087, 10.575285907374544, 11.453973739323326, 14.514002406931038]
fold_2_truth = [1.7758514390416337e-06, 7.434178379942826e-05, 0.025505105530754336, 2.3832621880559737, 12.229462419285989, 21.787555290078714, 24.206997180704818, 23.686138335640116, 24.467670354889798, 26.57020677792774, 25.61294391339852, 22.03086101375444, 18.16946343721228, 15.949065159044686, 14.340455467727908, 13.2960627458507, 12.621558248870935, 12.583941096288186, 13.183980790717547, 14.271670956304545, 16.159036152575005, 15.122237230521607, 12.840754302023626, 11.324767524578077, 11.144230472916039, 11.888232910744513, 14.130205989299895]
fold_3_predictions = [0.6127287523178655, 0.07980804885853808, 0.15874814003625407, 2.499238011722746, 8.944465402798741, 17.59709512110803, 21.87619899485478, 22.342813921876367, 24.02621276447487, 26.054553943476726, 24.791630901367547, 21.467216960217907, 17.579767871641632, 15.185564165129684, 13.830741003782574, 13.060178858838277, 12.695768376809307, 12.832359532582705, 13.669071297229864, 14.747004236767166, 15.870364956280222, 14.542832617228019, 12.244121745103275, 10.804928091986127, 10.650680276269556, 11.715136632725228, 15.30746541537723]
fold_3_truth = [2.4485252140269747e-06, 0.001381388956221639, 0.13099977579525612, 3.0316722416936885, 13.623208605909863, 23.043784519714322, 24.875293666415274, 24.073862546331785, 24.85386155456936, 26.654044145776382, 25.67575740639439, 22.19172144737135, 17.99190281322053, 15.603029166583644, 14.152089534290488, 13.340633331407638, 12.947154060231977, 12.975161622962226, 13.703051259597052, 14.738174242905904, 15.97102853741251, 14.75818180630807, 12.449681740261852, 10.879134957127677, 10.609000964774266, 11.433785221914551, 13.854911816850525]

# %% [markdown]
# Cell-based models on the respective validation sets

# %%
a = np.linspace(21, 47, 27)

# plt.rcParams['figure.figsize']  [6.0, 4.0]
fig = plt.figure(figsize=(8,16/3))

ax = fig.add_subplot(111, xlabel='Mean cl_volume', ylabel='Vertical layer')
ax.plot(fold_1_predictions, a, 'c', alpha=.7)
ax.plot(fold_1_truth, a, 'c--')
ax.plot(fold_2_predictions, a, 'm', alpha=.7)
ax.plot(fold_2_truth, a, 'm--')
ax.plot(fold_3_predictions, a, 'darkgreen', alpha=.7)
ax.plot(fold_3_truth, a, '--', color='darkgreen')
ax.grid(b=True)

ax.legend(['Model Fold 1 Predictions', 'Model Fold 1 Truth', 'Model Fold 2 Predictions', 
           'Model Fold 2 Truth', 'Model Fold 3 Predictions', 'Model Fold 3 Truth'])
plt.gca().invert_yaxis()
# fig.savefig('figures/r2b5_cell-based_validation_sets.pdf')

# %% [markdown]
# Cloud Area Fraction

# %%
fold_3_truth_cl_area = [1.6354747771620526e-05, 0.007483785543232006, 0.3712185693250039, 9.168092222200915, 24.080346674560023, 33.53375422201659, 36.253618391808715, 36.32031075199701, 36.526967222142204, 36.941889101750114, 34.9192749886559, 29.441743605240692, 26.91769727132959, 23.112241788794865, 23.25340308334162, 20.775423546479328, 20.698623337746678, 21.555481727570143, 23.5066945882286, 25.865433565215568, 24.900927389799953, 25.37202060229854, 19.172125898330574, 16.613032075871256, 15.187584797817292, 13.53822800830614, 12.605117922250258]

# %% [markdown]
# #### What would this look like in a single plot?

# %%
# a = np.linspace(21, 47, 27)

# plt.rcParams['figure.figsize']  [6.0, 4.0]
fig = plt.figure(figsize=(8,16/3))

ax = fig.add_subplot(111, xlabel='Mean cloud cover [%]', ylabel='z [km]')
ax.plot(fold_1_predictions, zg_mean_qubicc, color=color_1, alpha=.7, linewidth=3)
ax.plot(fold_1_truth, zg_mean_qubicc, '--', color=color_1, linewidth=3)
ax.plot(fold_2_predictions, zg_mean_qubicc, color=color_2, alpha=.7, linewidth=3)
ax.plot(fold_2_truth, zg_mean_qubicc, '--', color=color_2, linewidth=3)
ax.plot(fold_3_predictions, zg_mean_qubicc, color=color_3, alpha=.7, linewidth=3)
ax.plot(fold_3_truth, zg_mean_qubicc, '--', color=color_3, linewidth=3)

l1, = ax.plot(fold_1_predictions_cl_area, zg_mean_qubicc, color=color_1, alpha=.7)
l2, = ax.plot(fold_1_truth_cl_area, zg_mean_qubicc, '--', color=color_1)
l3, = ax.plot(fold_2_predictions_cl_area, zg_mean_qubicc, color=color_2, alpha=.7)
l4, = ax.plot(fold_2_truth_cl_area, zg_mean_qubicc, '--', color=color_2)
l5, = ax.plot(fold_3_predictions_cl_area, zg_mean_qubicc, color=color_3, alpha=.7)
l6, = ax.plot(fold_3_truth_cl_area, zg_mean_qubicc, '--', color=color_3)

ax.grid(b=True)

# ax.legend(['cl_vol pred 1', 'cl_vol truth 1', 'cl_vol pred 2', 'cl_vol truth 2', 'cl_vol pred 3', 'cl_vol truth 3', \
#            'cl_area pred 1', 'cl_area truth 1', 'cl_area pred 2', 'cl_area truth 2', 'cl_area pred 3', 'cl_area truth 3'])
legend_vol = ax.legend(['pred model 1', 'truth 1', 'pred model 2', 'truth 2', 'pred model 3', \
                                             'truth 3'], title = "cl_volume", loc=3, title_fontsize=13)
ax.legend([l1, l2, l3, l4, l5, l6], \
          ['pred model 1', 'truth 1', 'pred model 2', 'truth 2', 'pred model 3', 'truth 3'],
          title = "cl_area", loc=4, title_fontsize=13)
# plt.gca().invert_yaxis()
plt.gca().add_artist(legend_vol)
fig.savefig('figures/r2b5_cell-based_validation_sets.pdf')
