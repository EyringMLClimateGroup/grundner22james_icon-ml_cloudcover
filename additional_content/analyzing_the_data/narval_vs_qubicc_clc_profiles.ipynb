# %% [markdown]
# True cloud cover profiles of QUBICC and NARVAL

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# NARVAL
cl_cover_R02B04_not_nan_mean = np.array([2.04788328e-07,3.37767572e-04,1.76278977e-01,1.50058592e+00,3.90944700e+00,6.37033329e+00,6.56155277e+00,5.03742503e+00,3.44565701e+00,2.57724830e+00,1.92405911e+00,1.66570785e+00,1.98510114e+00,2.45446022e+00,2.20961668e+00,1.74880456e+00,1.96377226e+00,2.76433093e+00,4.17553670e+00,6.91707966e+00,1.07888452e+01,1.33122431e+01,1.07748726e+01,4.34056985e+00,9.92240911e-01,3.40039166e-01,0])

# QUBICC
cl_cover_R02B05_not_nan_mean = np.array([1.22217889e-08,1.75145256e-06,1.84245979e-04,9.93234268e-03,6.59599915e-02,1.29870176e-01,1.51542476e-01,1.54723993e-01,1.62250742e-01,1.73156397e-01,1.64811906e-01,1.37327607e-01,1.10936298e-01,9.31128195e-02,8.35969191e-02,7.62606061e-02,7.44015863e-02,7.77238845e-02,8.79327189e-02,1.03564707e-01,1.19543717e-01,1.17182745e-01,9.22144978e-02,6.74581415e-02,5.58105779e-02,5.47176857e-02,0])

tropics_data_mean = [4.1146270133245254e-08,1.1454347739332849e-05,0.0008787377048260461,0.7018365674514352,9.093122613222596,20.811720657294902,21.308662579780243,16.309228670323286,12.799764612059871,11.936130301132959,9.270457168635234,4.887311912322771,2.709611858241172,2.1625269037151047,2.0852971463010825,1.4426236638538807,1.2152209043481799,1.344845087069636,1.6736569298949755,2.1793370739163094,2.7954045728771217,2.950703574410408,1.8810279700451213,0.7465174422858805,0.383964788063811,0.32092803072459913,0.3423620304183509]

# %%
plt.figure(figsize=(8,5))
a = np.arange(len(tropics_data_mean)) + 21

plt.plot(np.array(cl_cover_R02B04_not_nan_mean), a)
plt.plot(tropics_data_mean, a, color='orange')
plt.plot(100*np.array(cl_cover_R02B05_not_nan_mean), a, color='orange', ls='--')
plt.ylabel('Vertical layer')
plt.xlabel('Mean clc')

plt.legend(['NARVAL', 'QUBICC: NARVAL region', 'QUBICC'], loc='lower right')

plt.gca().invert_yaxis()
